# %%
from datasets import load_dataset
ds = load_dataset("uonlp/CulturaX",
                  "fr")
# Out:
# Resolving data files:   0%|          | 0/512 [00:00<?, ?it/s]
# ...
# fr_part_00000.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# fr_part_00001.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# fr_part_00002.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# fr_part_00003.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# fr_part_00004.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# fr_part_00005.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
# fr_part_00006.parquet:   0%|          | 0.00/1.55G [00:00<?, ?B/s]
